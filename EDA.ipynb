# %%
import os
import pandas as pd
import numpy as np

# %%
articles = 'BBC News Summary/News Articles/'
summaries = 'BBC News Summary/Summaries/'

# %%
cats = os.listdir('BBC News Summary/News Articles')
cats
# Out:
# ['entertainment', 'business', 'sport', 'politics', 'tech']

# %%
os.listdir('BBC News Summary/Summaries')
# Out:
# ['entertainment', 'business', 'sport', 'politics', 'tech']

# %%
try:
    for cat in cats:
        print(cat)
        #make sure all the files in articles are also in summaries vice versa too
        arts = os.listdir(articles + cat)
        sums = os.listdir(summaries + cat)
        assert( arts == sums )
        #make sure no files are missing
        ids = [int(a[:a.find('.')]) for a in arts]
        ids.sort()
        assert(ids == list(range(1, max(ids) + 1)))

        #create csv
        art_text = []
        sum_text = []
        for file in arts:
            with open(articles + cat + '/' + file, 'r') as f:
                text = f.read()
                assert(text.find('\t') == -1)
                text = text[text.find('\n') + 1:]
                art_text.append(text.replace('\n', ' '))
            with open(articles + cat + '/' + file, 'r') as f:
                text = f.read()
                assert(text.find('\t') == -1)
                text = text[text.find('\n') + 1:]
                sum_text.append(text.replace('\n', ' '))
        data = [ids, art_text, sum_text]
        df = pd.DataFrame(np.array(data).T, columns = ['id', 'article', 'summary'])
        df.to_csv(cat + '.tsv', '\t')
        print(df)
except:
    print('ERROR')
    print(articles + cat + '/' + file)
    assert(false)

#removed pound symbol in sport/199.txt, replaced with dollar since it is not utf 8
# Out:
# entertainment
#       id                                            article  \
# 0      1   Musicians' groups are to tackle US visa regul...
# 1      2   U2, who have won three prestigious Grammy Awa...
# 2      3   Rock singer Pete Doherty has been involved in...
# 3      4   The film adaptation of Lemony Snicket novels ...
# 4      5   Ocean's Twelve, the crime caper sequel starri...
# ..   ...                                                ...
# 381  382   The Aviator has been tipped by UK bookmakers ...
# 382  383   US band Scissor Sisters led the winners at th...
# 383  384   Singer Britney Spears is suing eight insuranc...
# 384  385   Angels by Robbie Williams is the song Britons...
# 385  386   DJ duo JK and Joel are taking over BBC Radio ...
#
#                                                summary
# 0     Musicians' groups are to tackle US visa regul...
# 1     U2, who have won three prestigious Grammy Awa...
# 2     Rock singer Pete Doherty has been involved in...
# 3     The film adaptation of Lemony Snicket novels ...
# 4     Ocean's Twelve, the crime caper sequel starri...
# ..                                                 ...
# 381   The Aviator has been tipped by UK bookmakers ...
# 382   US band Scissor Sisters led the winners at th...
# 383   Singer Britney Spears is suing eight insuranc...
# 384   Angels by Robbie Williams is the song Britons...
# 385   DJ duo JK and Joel are taking over BBC Radio ...
#
# [386 rows x 3 columns]
# business
#       id                                            article  \
# 0      1   The UK manufacturing sector will continue to ...
# 1      2   Climate change and the fight against Aids are...
# 2      3   Shares in Europe's leading reinsurers and tra...
# 3      4   Shares in India's largest power producer, Nat...
# 4      5   Luxury goods group LVMH has sold its loss-mak...
# ..   ...                                                ...
# 505  506   The US created fewer jobs than expected in Ja...
# 506  507   Strong sales outside western Europe helped Re...
# 507  508   More than 90% of large companies around the w...
# 508  509   The Bank of England has left interest rates o...
# 509  510   Beyond the desperate security situation in Ir...
#
#                                                summary
# 0     The UK manufacturing sector will continue to ...
# 1     Climate change and the fight against Aids are...
# 2     Shares in Europe's leading reinsurers and tra...
# 3     Shares in India's largest power producer, Nat...
# 4     Luxury goods group LVMH has sold its loss-mak...
# ..                                                 ...
# 505   The US created fewer jobs than expected in Ja...
# 506   Strong sales outside western Europe helped Re...
# 507   More than 90% of large companies around the w...
# 508   The Bank of England has left interest rates o...
# 509   Beyond the desperate security situation in Ir...
#
# [510 rows x 3 columns]
# sport
#       id                                            article  \
# 0      1   England coach Andy Robinson insisted he was "...
# 1      2   Conchita Martinez won her first title in almo...
# 2      3   Tottenham are primed to snap up Iceland Under...
# 3      4   Mexican outfit Red Sharks Veracruz hope to si...
# 4      5   Teenager Sania Mirza completed a superb week ...
# ..   ...                                                ...
# 506  507   Celtic's Henri Camara and Nacho Novo of Range...
# 507  508   Real Madrid and Real Socieded will play the f...
# 508  509   Second seed Andre Agassi suffered a comprehen...
# 509  510   Ireland fly-half Ronan O'Gara hailed his side...
# 510  511   Fly-half Charlie Hodgson admitted his wayward...
#
#                                                summary
# 0     England coach Andy Robinson insisted he was "...
# 1     Conchita Martinez won her first title in almo...
# 2     Tottenham are primed to snap up Iceland Under...
# 3     Mexican outfit Red Sharks Veracruz hope to si...
# 4     Teenager Sania Mirza completed a superb week ...
# ..                                                 ...
# 506   Celtic's Henri Camara and Nacho Novo of Range...
# 507   Real Madrid and Real Socieded will play the f...
# 508   Second seed Andre Agassi suffered a comprehen...
# 509   Ireland fly-half Ronan O'Gara hailed his side...
# 510   Fly-half Charlie Hodgson admitted his wayward...
#
# [511 rows x 3 columns]
# politics
#       id                                            article  \
# 0      1   Former Labour leader Neil Kinnock has officia...
# 1      2   Tony Blair's feud with Gordon Brown is damagi...
# 2      3   The reported feud between Tony Blair and Gord...
# 3      4   Billions of pounds spent on conflict in Iraq ...
# 4      5   The leader of the British National Party has ...
# ..   ...                                                ...
# 412  413   Michael Howard has backed stem cell research,...
# 413  414   Tony Blair has dismissed reports he told Gord...
# 414  415   Charles Kennedy is set to address 2,000 peopl...
# 415  416   The Lord Chancellor has defended government p...
# 416  417   Charles Kennedy is far too canny to make any ...
#
#                                                summary
# 0     Former Labour leader Neil Kinnock has officia...
# 1     Tony Blair's feud with Gordon Brown is damagi...
# 2     The reported feud between Tony Blair and Gord...
# 3     Billions of pounds spent on conflict in Iraq ...
# 4     The leader of the British National Party has ...
# ..                                                 ...
# 412   Michael Howard has backed stem cell research,...
# 413   Tony Blair has dismissed reports he told Gord...
# 414   Charles Kennedy is set to address 2,000 peopl...
# 415   The Lord Chancellor has defended government p...
# 416   Charles Kennedy is far too canny to make any ...
#
# [417 rows x 3 columns]
# tech
#       id                                            article  \
# 0      1   Mobile phones in the UK are celebrating their...
# 1      2   More and more Americans are joining the inter...
# 2      3   Video game giant Electronic Arts (EA) says it...
# 3      4   Microsoft has warned PC users to update their...
# 4      5   The Chinese net-using population looks set to...
# ..   ...                                                ...
# 396  397   Writing a Microsoft Word document can be a da...
# 397  398   Two high-speed lifts at the world's tallest b...
# 398  399   Nintendo is releasing an adapter for its DS h...
# 399  400   Security firms are warning about several mobi...
# 400  401   Users of Apple's music jukebox iTunes need to...
#
#                                                summary
# 0     Mobile phones in the UK are celebrating their...
# 1     More and more Americans are joining the inter...
# 2     Video game giant Electronic Arts (EA) says it...
# 3     Microsoft has warned PC users to update their...
# 4     The Chinese net-using population looks set to...
# ..                                                 ...
# 396   Writing a Microsoft Word document can be a da...
# 397   Two high-speed lifts at the world's tallest b...
# 398   Nintendo is releasing an adapter for its DS h...
# 399   Security firms are warning about several mobi...
# 400   Users of Apple's music jukebox iTunes need to...
#
# [401 rows x 3 columns]
